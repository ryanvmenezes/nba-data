# %%
import os
from time import sleep
from tqdm import tqdm

# %% [markdown]
# Gets a list of all regular-season games for a season

# %%
from nba_api.stats.endpoints import commonallplayers

# %%
req = commonallplayers.CommonAllPlayers()
df = req.common_all_players.get_data_frame()

# %%
df
# Out:
#       PERSON_ID DISPLAY_LAST_COMMA_FIRST   DISPLAY_FIRST_LAST  ROSTERSTATUS  \
# 0         76001          Abdelnaby, Alaa       Alaa Abdelnaby             0
# 1         76002         Abdul-Aziz, Zaid      Zaid Abdul-Aziz             0
# 2         76003     Abdul-Jabbar, Kareem  Kareem Abdul-Jabbar             0
# 3            51      Abdul-Rauf, Mahmoud   Mahmoud Abdul-Rauf             0
# 4          1505       Abdul-Wahad, Tariq    Tariq Abdul-Wahad             0
# ...         ...                      ...                  ...           ...
# 4504    1627790              Zizic, Ante           Ante Zizic             1
# 4505      78647                Zoet, Jim             Jim Zoet             0
# 4506      78648               Zopf, Bill            Bill Zopf             0
# 4507    1627826             Zubac, Ivica          Ivica Zubac             1
# 4508      78650              Zunic, Matt           Matt Zunic             0
#
# ...

# %%
df.to_csv('commonallplayers.csv', index=False)
